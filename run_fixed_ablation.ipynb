# %% [markdown]
# # Honest ablation: does the complement OPERATION beat just bert_maxsim pooling?
#
# Non-circular **retrieval** metric (does delta_i identify ITS OWN novel content among all
# pairs?) + ablation across constructions (enc_B / gate_only / gate_sub / sub_only /
# gold_novel). Zero training, ~minutes. The key comparison is **gate_sub vs gate_only**
# (does the subtraction add anything) and **gate_* vs enc_B** (does novelty selection help).

# %%
# Cell 1 - install + clone/pull
# !pip install transformers scikit-learn scipy datasets -q
import os, sys
from pathlib import Path
REPO = Path('/kaggle/working/multihop-retrieval')
if REPO.exists():
    os.system(f'git -C {REPO} pull')
else:
    os.system(f'git clone https://github.com/haaaaaaayrewugrhyw/multihop-retrieval.git {REPO}')
sys.path.insert(0, str(REPO / 'delta_system'))
print('OK')

# %%
# Cell 2 - run the ablation + retrieval test
import subprocess, sys
cmd = [
    sys.executable,
    '/kaggle/working/multihop-retrieval/delta_system/fixed_complement_ablation.py',
    '--n',   '500',
    '--tau', '0.1',
]
r = subprocess.run(cmd)
print('exit code', r.returncode)
