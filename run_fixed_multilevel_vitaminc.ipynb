# %% [markdown]
# # Multi-level fixed complement on VitaminC factual flips (zero training)
#
# Tests the hierarchical idea on the HARD case: compute the fixed op at BERT layers 1/4/8/12
# (surface->semantic), per-layer + combined, retrieval of the factual change. Last-layer-only
# was 0.179. Does a surface/early layer or the combination beat it (capturing subtle flips)?

# %%
# Cell 1 - install + clone/pull
# !pip install transformers scikit-learn scipy datasets -q
import os, sys
from pathlib import Path
REPO = Path('/kaggle/working/multihop-retrieval')
if REPO.exists():
    os.system(f'git -C {REPO} pull')
else:
    os.system(f'git clone https://github.com/haaaaaaayrewugrhyw/multihop-retrieval.git {REPO}')
sys.path.insert(0, str(REPO / 'delta_system'))
print('OK')

# %%
# Cell 2 - run the multi-level VitaminC test
import subprocess, sys
cmd = [
    sys.executable,
    '/kaggle/working/multihop-retrieval/delta_system/fixed_multilevel_vitaminc.py',
    '--n',   '2000',
    '--tau', '0.1',
]
r = subprocess.run(cmd)
print('exit code', r.returncode)
