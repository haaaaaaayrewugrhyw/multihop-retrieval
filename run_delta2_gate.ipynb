# %% [markdown]
# # Delta-2: GATE test (the other half of gate->extract)
#
# Can the pooled surface-invariant delta separate real edits from paraphrases by ||delta||? This is
# the half the token extractor failed (magnitude AUC 0.43). High AUC (esp. on relational/numeric) =>
# gate->extract validated. GPU on; HF_TOKEN secret attached.

# %%
# !pip install transformers scikit-learn scipy datasets -q
import subprocess, sys, os
from pathlib import Path
from kaggle_secrets import UserSecretsClient
_t = UserSecretsClient().get_secret('HF_TOKEN')
os.environ['HF_TOKEN'] = _t; os.environ['HUGGING_FACE_HUB_TOKEN'] = _t
print('HF token: loaded in kernel')
REPO = Path('/kaggle/working/multihop-retrieval')
if not REPO.exists():
    os.system(f'git clone https://github.com/haaaaaaayrewugrhyw/multihop-retrieval.git {REPO}')
else:
    print(os.popen(f'git -C {REPO} pull').read())
subprocess.run([sys.executable, '-u', str(REPO/'delta_system'/'delta2_gate_test.py'), '--n_edit', '400', '--steps', '600'])
