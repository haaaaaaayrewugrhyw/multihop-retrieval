# %% [markdown]
# # Delta-2B STEP 2: architecture sanity-train
#
# Token-level subtraction backbone + RTD/content/anchor heads + 5 objectives (uncertainty-weighted).
# Confirms it learns: rtd_acc up, content_cos up, edit/syn separation >1, plus the PULL-vs-gate
# gradient-cosine diagnostic. GPU + HF_TOKEN. See DELTA2_BUILD_SPEC.md.

# %%
# !pip install transformers scikit-learn scipy datasets nltk -q
import subprocess, sys, os
from pathlib import Path
from kaggle_secrets import UserSecretsClient
_t = UserSecretsClient().get_secret('HF_TOKEN')
os.environ['HF_TOKEN'] = _t; os.environ['HUGGING_FACE_HUB_TOKEN'] = _t
print('HF token: loaded in kernel')
REPO = Path('/kaggle/working/multihop-retrieval')
if not REPO.exists():
    os.system(f'git clone https://github.com/haaaaaaayrewugrhyw/multihop-retrieval.git {REPO}')
else:
    print(os.popen(f'git -C {REPO} pull').read())
subprocess.run([sys.executable, '-u', str(REPO/'delta_system'/'delta2b_model.py'), '--n', '400', '--steps', '300'])
