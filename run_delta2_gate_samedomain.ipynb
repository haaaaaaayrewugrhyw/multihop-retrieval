# %% [markdown]
# # Delta-2: SAME-DOMAIN gate test (rule out the domain confound)
#
# The 0.99 gate used MRPC(news) paraphrases vs wiki edits -> could be domain, not meaning-change.
# This uses same-domain negatives: IteraTeR meaning-changed (edit=1) vs IteraTeR non-meaning
# (fluency/clarity = meaning-preserving, edit=0). High AUC here = the gate is real. GPU + HF_TOKEN.

# %%
# !pip install transformers scikit-learn scipy datasets -q
import subprocess, sys, os
from pathlib import Path
from kaggle_secrets import UserSecretsClient
_t = UserSecretsClient().get_secret('HF_TOKEN')
os.environ['HF_TOKEN'] = _t; os.environ['HUGGING_FACE_HUB_TOKEN'] = _t
print('HF token: loaded in kernel')
REPO = Path('/kaggle/working/multihop-retrieval')
if not REPO.exists():
    os.system(f'git clone https://github.com/haaaaaaayrewugrhyw/multihop-retrieval.git {REPO}')
else:
    print(os.popen(f'git -C {REPO} pull').read())
subprocess.run([sys.executable, '-u', str(REPO/'delta_system'/'delta2_gate_samedomain.py'), '--n', '400', '--steps', '600'])
