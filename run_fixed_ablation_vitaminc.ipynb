# %% [markdown]
# # Correct semantic test: retrieval of the FACTUAL CHANGE on VitaminC (zero training)
#
# The SUPPORTS/REFUTES probe was ill-posed (delta never sees the claim). This uses the valid
# target delta CAN encode — the changed content — via the same non-circular retrieval as the
# IteraTeR ablation, now on subtle factual flips (replaces). If gate_sub stays ~0.92 here,
# delta captures SEMANTIC change, not just inserted text.

# %%
# Cell 1 - install + clone/pull
# !pip install transformers scikit-learn scipy datasets -q
import os, sys
from pathlib import Path
REPO = Path('/kaggle/working/multihop-retrieval')
if REPO.exists():
    os.system(f'git -C {REPO} pull')
else:
    os.system(f'git clone https://github.com/haaaaaaayrewugrhyw/multihop-retrieval.git {REPO}')
sys.path.insert(0, str(REPO / 'delta_system'))
print('OK')

# %%
# Cell 2 - run the VitaminC factual-flip retrieval ablation
import subprocess, sys
cmd = [
    sys.executable,
    '/kaggle/working/multihop-retrieval/delta_system/fixed_ablation_vitaminc.py',
    '--n',   '2000',
    '--tau', '0.1',
]
r = subprocess.run(cmd)
print('exit code', r.returncode)
