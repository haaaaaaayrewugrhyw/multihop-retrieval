# %% [markdown]
# # Delta-2 STEP 1: data foundation go/no-go check
#
# Validates the data the whole multi-task experiment rests on (see delta_system/DELTA2_DESIGN.md):
# change-type stratification of real edits (IteraTeR insertions + VitaminC factual flips),
# NLI-teacher labels on (A,B), and paraphrase negatives validated by bidirectional-NLI + lexical
# filter. Prints a GO / FIX verdict. No training, no architecture change.

# %%
# Cell 1 - install + clone/pull
# !pip install transformers scikit-learn scipy datasets -q
import os, sys
from pathlib import Path
REPO = Path('/kaggle/working/multihop-retrieval')
if REPO.exists():
    os.system(f'git -C {REPO} pull')
else:
    os.system(f'git clone https://github.com/haaaaaaayrewugrhyw/multihop-retrieval.git {REPO}')
sys.path.insert(0, str(REPO / 'delta_system'))
print('OK')

# %%
# Cell 2 - run the data foundation check
import subprocess, sys
cmd = [
    sys.executable,
    '/kaggle/working/multihop-retrieval/delta_system/delta2_data.py',
    '--n_edit', '600',
    '--n_para', '600',
]
r = subprocess.run(cmd)
print('exit code', r.returncode)
