# %% [markdown]
# # Delta-3 clean: original arch + small bottleneck + NO A-dropout, on WikiAtomicEdits (Yin's data)
#
# Single regeneration objective. Tests whether the bottleneck + removing A-dropout fixes the
# collapse, on the SAME dataset as Yin et al. 2019. Reports greedy exact-match (vs Yin Acc@1 0.729)
# and the A-dependence collapse diagnostic. No copy mechanism (original arch only). GPU + HF_TOKEN.

# %%
# !pip install transformers scikit-learn scipy datasets nltk -q
import subprocess, sys, os
from pathlib import Path
from kaggle_secrets import UserSecretsClient
_t = UserSecretsClient().get_secret('HF_TOKEN')
os.environ['HF_TOKEN'] = _t; os.environ['HUGGING_FACE_HUB_TOKEN'] = _t
print('HF token: loaded in kernel')
REPO = Path('/kaggle/working/multihop-retrieval')
if not REPO.exists():
    os.system(f'git clone https://github.com/haaaaaaayrewugrhyw/multihop-retrieval.git {REPO}')
else:
    print(os.popen(f'git -C {REPO} pull').read())
subprocess.run([sys.executable, '-u', str(REPO/'delta_system'/'delta3_clean.py'), '--n','4000','--steps','3000'])
