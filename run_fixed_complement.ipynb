# %% [markdown]
# # Fixed match-scaled complement on real BERT (zero training)
#
# Tests the fixed-subtraction idea in its cheapest form: NO training, frozen BERT, single
# level. Computes the match-scaled complement on real IteraTeR edits and checks:
# - **[A] localization** (does the gate flag inserted tokens? AUC)
# - **[B] content** (does the delta VECTOR point at NOVEL content more than plain encode(B)?)
#
# Decisive yes/no in ~minutes. GPU ON, Internet ON.

# %%
# Cell 1 - install + clone/pull
# !pip install transformers scikit-learn scipy datasets -q
import os, sys
from pathlib import Path
REPO = Path('/kaggle/working/multihop-retrieval')
if REPO.exists():
    os.system(f'git -C {REPO} pull')
else:
    os.system(f'git clone https://github.com/haaaaaaayrewugrhyw/multihop-retrieval.git {REPO}')
sys.path.insert(0, str(REPO / 'delta_system'))
print('OK')

# %%
# Cell 2 - run the zero-training fixed-complement test
import subprocess, sys
cmd = [
    sys.executable,
    '/kaggle/working/multihop-retrieval/delta_system/fixed_complement_eval.py',
    '--n',   '500',
    '--tau', '0.1',
]
r = subprocess.run(cmd)
print('exit code', r.returncode)
