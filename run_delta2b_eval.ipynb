# %% [markdown]
# # Delta-2B STEP 5: held-out evaluation of the single model
#
# Trains one Delta2B on a train split, then on HELD-OUT test reports: content retrieval (vs
# complement 0.76 / encB / oracle), gate AUC edit-vs-(syn+non), A-dependence, A-leak, and END-TO-END
# vs the 0.82 two-stage baseline. Multi-seed. GPU + HF_TOKEN. See DELTA2_BUILD_SPEC.md.

# %%
# !pip install transformers scikit-learn scipy datasets nltk -q
import subprocess, sys, os
from pathlib import Path
from kaggle_secrets import UserSecretsClient
_t = UserSecretsClient().get_secret('HF_TOKEN')
os.environ['HF_TOKEN'] = _t; os.environ['HUGGING_FACE_HUB_TOKEN'] = _t
print('HF token: loaded in kernel')
REPO = Path('/kaggle/working/multihop-retrieval')
if not REPO.exists():
    os.system(f'git clone https://github.com/haaaaaaayrewugrhyw/multihop-retrieval.git {REPO}')
else:
    print(os.popen(f'git -C {REPO} pull').read())
subprocess.run([sys.executable, '-u', str(REPO/'delta_system'/'delta2b_eval.py'), '--n', '400', '--steps', '400', '--seeds', '2'])
