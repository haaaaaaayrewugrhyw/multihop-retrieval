# %% [markdown]
# # Delta-2: token-level complement battery (zero-training, held-out, stratified)
#
# The decisive remaining measurement: run the token-level match-scaled complement on the SAME
# held-out edits, stratified by change-type, with the oracle per type. Gives the bar (does 0.92
# hold), the per-type breakdown, and the encoder ceiling (oracle per type). GPU on; HF_TOKEN secret
# attached.

# %%
# !pip install transformers scikit-learn scipy datasets -q
import subprocess, sys, os
from pathlib import Path
from kaggle_secrets import UserSecretsClient
_t = UserSecretsClient().get_secret('HF_TOKEN')
os.environ['HF_TOKEN'] = _t; os.environ['HUGGING_FACE_HUB_TOKEN'] = _t
print('HF token: loaded in kernel')
REPO = Path('/kaggle/working/multihop-retrieval')
if not REPO.exists():
    os.system(f'git clone https://github.com/haaaaaaayrewugrhyw/multihop-retrieval.git {REPO}')
else:
    print(os.popen(f'git -C {REPO} pull').read())
subprocess.run([sys.executable, '-u', str(REPO/'delta_system'/'delta2_token_battery.py'),
                '--n_edit', '400', '--tau', '0.1'])
