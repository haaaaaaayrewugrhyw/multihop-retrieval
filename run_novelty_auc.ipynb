# %%
# Cell 1 — Setup
# Requires: Wikipedia training already run so wiki_model.pt exists
# (run kaggle_notebook.ipynb first, or any training that saves to /kaggle/working/checkpoints/)

# !pip install transformers scikit-learn datasets scipy -q

import os, sys
from pathlib import Path

REPO = Path('/kaggle/working/multihop-retrieval')
if REPO.exists():
    os.system(f'git -C {REPO} pull')
else:
    os.system(f'git clone https://github.com/haaaaaaayrewugrhyw/multihop-retrieval.git {REPO}')

sys.path.insert(0, str(REPO / 'delta_system'))
print('Files:', sorted([f.name for f in (REPO/'delta_system').glob('*.py')]))

# Show available checkpoints
import glob
ckpts = glob.glob('/kaggle/working/checkpoints/*.pt')
print('Checkpoints found:', ckpts)

# %%
# Cell 2 — Run zero-shot novelty AUC evaluation
# Loads the Wikipedia checkpoint, evaluates on 1000 fresh pairs (never used in training)
# Compares delta norm vs vocab_novelty (independent label) and TF-IDF baseline

# !python /kaggle/working/multihop-retrieval/delta_system/novelty_auc_eval.py \
    --ckpt /kaggle/working/checkpoints/wiki_model.pt \
    --n 1000 \
    --skip 10000
