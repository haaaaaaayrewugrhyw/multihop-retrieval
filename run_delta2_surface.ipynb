# %% [markdown]
# # Delta-2: surface-robustness of the token-level complement (claim #3)
#
# Does the 0.76 token-level extractor over-fire on meaning-preserving paraphrases? We compare its
# novelty magnitude on real edits (A,B) vs validated paraphrases (A,A_para). High AUC separating
# edit-from-paraphrase = surface-robust; ~0.5 = surface-driven (over-fires). Stratified by
# change-type. GPU on; HF_TOKEN secret attached.

# %%
# !pip install transformers scikit-learn scipy datasets -q
import subprocess, sys, os
from pathlib import Path
from kaggle_secrets import UserSecretsClient
_t = UserSecretsClient().get_secret('HF_TOKEN')
os.environ['HF_TOKEN'] = _t; os.environ['HUGGING_FACE_HUB_TOKEN'] = _t
print('HF token: loaded in kernel')
REPO = Path('/kaggle/working/multihop-retrieval')
if not REPO.exists():
    os.system(f'git clone https://github.com/haaaaaaayrewugrhyw/multihop-retrieval.git {REPO}')
else:
    print(os.popen(f'git -C {REPO} pull').read())
subprocess.run([sys.executable, '-u', str(REPO/'delta_system'/'delta2_surface_robust.py'), '--n_edit', '400'])
