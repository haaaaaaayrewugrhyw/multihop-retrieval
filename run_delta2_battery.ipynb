# %% [markdown]
# # Delta-2 STEP 3: measurement battery (held-out, non-circular)
#
# Trains the scaffold under each aux on a group-split TRAIN set, then measures every rep on the
# HELD-OUT test set vs baselines/oracle/chance: effective rank, content retrieval (stratified),
# surface-invariance on held-out paraphrases, A-dependence (shuffled-A), and the NLI meaning probe
# (acc / selectivity / MDL). The circular step-2 train metrics are gone here.
#
# GPU T4 x2 on. Restart the session if a previous run was cancelled (zombies hold RAM).

# %%
# !pip install transformers scikit-learn scipy datasets -q
import subprocess, sys, os
from pathlib import Path
from kaggle_secrets import UserSecretsClient
_t = UserSecretsClient().get_secret('HF_TOKEN')
os.environ['HF_TOKEN'] = _t; os.environ['HUGGING_FACE_HUB_TOKEN'] = _t
print('HF token: loaded in kernel')
REPO = Path('/kaggle/working/multihop-retrieval')
if not REPO.exists():
    os.system(f'git clone https://github.com/haaaaaaayrewugrhyw/multihop-retrieval.git {REPO}')
else:
    print(os.popen(f'git -C {REPO} pull').read())
subprocess.run([sys.executable, '-u', str(REPO/'delta_system'/'delta2_eval.py'), '--steps', '600'])
