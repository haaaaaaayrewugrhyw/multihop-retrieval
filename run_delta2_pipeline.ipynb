# %% [markdown]
# # Delta-2: INTEGRATED gate->extract pipeline (end-to-end, same-domain)
#
# Assembles the validated pieces into one system: gate (best of ||delta|| vs NLI) decides 'did
# meaning change?', then the zero-training token complement extracts 'what changed'. Reports one
# honest end-to-end number (gated AND content-correct), stratified by change-type. GPU + HF_TOKEN.

# %%
# !pip install transformers scikit-learn scipy datasets -q
import subprocess, sys, os
from pathlib import Path
from kaggle_secrets import UserSecretsClient
_t = UserSecretsClient().get_secret('HF_TOKEN')
os.environ['HF_TOKEN'] = _t; os.environ['HUGGING_FACE_HUB_TOKEN'] = _t
print('HF token: loaded in kernel')
REPO = Path('/kaggle/working/multihop-retrieval')
if not REPO.exists():
    os.system(f'git clone https://github.com/haaaaaaayrewugrhyw/multihop-retrieval.git {REPO}')
else:
    print(os.popen(f'git -C {REPO} pull').read())
subprocess.run([sys.executable, '-u', str(REPO/'delta_system'/'delta2_pipeline.py'), '--n', '400', '--steps', '600'])
